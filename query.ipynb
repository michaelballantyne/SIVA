# %%
from my_inspect import inspect_file
from my_load import load
from my_download import download
from my_render import render
from my_compress import compress

dataset = inspect_file("/projects/autonomousvis/ashrestha/code/VisLang/csafe_heptane_302x302x302_uint8.raw")
#dataset = inspect_file("/projects/exasky/data/hacc/SCIDAC_RUNS/128MPC_RUNS_FLAMINGO_DESIGN_3A/FSN_0.5387_VEL_149.279_TEXP_9.613_BETA_0.8710_SEED_1.387e5/output/m000p.full.mpicosmo.567")
#dataset = inspect_file("/projects/exasky/data/nyx/highz/512/NVB_C009_l10n512_S12345T692_z42.hdf5")
# Out:
# [VisLang] No built-in reader (yt/HDF5/FITS/GenericIO) recognized
# 'csafe_heptane_302x302x302_uint8.raw' — checking generated adapters.
# [VisLang] Loaded frozen adapter 'npz (LLM)' from /vast/projects/autonomousvis/ashrestha/code/VisLang/generated_adapters/npz.py
# [VisLang] No frozen adapter matches — asking the LLM to identify the format and write a reader module.
# [VisLang] Gathering evidence: csafe_heptane_302x302x302_uint8.raw (27.5 MB, ext '.raw')
# [VisLang] LLM attempt 1/4: asking for inspect() + read_array() module...
# [VisLang]   generated: FILETYPE='raw_volume', EXTENSIONS=['.raw'] (99 lines)
# [VisLang]   conformance: inspect() OK — 1 variables ['csafe_heptane'], dimensions={'grid': (302, 302, 302)}
# [VisLang]   conformance: read_array('csafe_heptane') OK — shape (302, 302, 302), dtype uint8
# [VisLang] ✓ adapter 'raw_volume (LLM)' validated and frozen to /vast/projects/autonomousvis/ashrestha/code/VisLang/generated_adapters/raw.py — future .raw files skip the LLM.

# %%
#print(dataset)

print("xx----------------------------xx")
print("FileType: ",dataset.filetype)
print("Variables: ", dataset.variables)
print("Dimensions: ", dataset.dimensions)

# %%
loadedFull = load(dataset, dataset.variables)

# %%
print(loadedFull)
# Out:
# File: /projects/autonomousvis/ashrestha/code/VisLang/csafe_heptane_302x302x302_uint8.raw
# Type: raw_volume (LLM)
#
# Available Variables (1):
#   - csafe_heptane
#
# Dimensions:
#   - grid: (302, 302, 302)
#
# ==================================================
# LOADED DATA:
#
# Loaded Variables (1):
#   - csafe_heptane: shape=(302, 302, 302), dtype=uint8
#
# Selection Applied:
#   - variables_loaded: ['csafe_heptane']
#   - dimension_selection: None
#   - grid_shape_loaded: (302, 302, 302)
#
# Attributes:
#   - dtype: uint8
#   - shape: [302, 302, 302]
#   - filename: csafe_heptane_302x302x302_uint8.raw

# %%
render(loadedFull)
# Out:
# ============================================================
# RENDERING DATASET (Server Mode)
# ============================================================
#
# Detected volumetric (3D) data — using volume renderer
#
# Rendering 1 volumetric field(s) via k3d (as loaded, no downsampling)...
# ⚠️  WARNING: large grids detected (~105 MB total will be sent to the browser).
#    Consider loading at lower resolution, e.g.: load(dataset, vars, dimensions={'grid': 64})
#   • csafe_heptane  (302, 302, 302)
#     ✓ added
# Output()
# ✓ All 1 field(s) rendered — rotate/zoom in the widget above

# %%
print(dataset.variables)

# %%
compressFull = compress(loadedFull, loadedFull.variables, error_bound=0.01)

# %%
from my_compress import print_compression_summary
print_compression_summary(compressFull)

# %%
compressedData = compress(loadedSubset, loadedSubset.variables, error_bound=0.01)

# %%
from my_compress import print_compression_summary
print_compression_summary(compressedData)

# %%
import k3d, numpy as np
v = np.random.rand(48, 48, 48).astype(np.float32)
p = k3d.plot()
p += k3d.volume(v)
p.display()

# %%
import k3d, numpy as np
p = k3d.plot()
p += k3d.points(np.random.rand(2000,3).astype(np.float32), point_size=0.02)
p.display()

# %%
from IPython.display import IFrame
IFrame('k3d_standalone_test.html', width=900, height=650)
