# %%
from my_inspect import inspect_file
from my_load import load
from my_download import download
from my_render import render

dataset = inspect_file("/projects/exasky/data/hacc/SCIDAC_RUNS/128MPC_RUNS_FLAMINGO_DESIGN_3A/FSN_0.5387_VEL_149.279_TEXP_9.613_BETA_0.8710_SEED_1.387e5/output/m000p.full.mpicosmo.567")
# Out:
# Read 17 variables from /projects/exasky/data/hacc/SCIDAC_RUNS/128MPC_RUNS_FLAMINGO_DESIGN_3A/FSN_0.5387_VEL_149.279_TEXP_9.613_BETA_0.8710_SEED_1.387e5/output/m000p.full.mpicosmo.567 (8914511260 bytes) in 22.3365s: 380.612 MB/s [excluding header read]

# %%
#print(dataset)

print("xx------------------- ---------xx")
print("FileType: ",dataset.filetype)
print("Variables: ", dataset.variables)
print("Dimensions: ", dataset.dimensions)
# Out:
# xx-----------------------------xx
# FileType:  HDF5
# Variables:  ['derived_fields/HI_number_density', 'derived_fields/HeIII_number_density', 'derived_fields/tau_local', 'derived_fields/tau_real', 'derived_fields/tau_red', 'derived_fields/tau_red_heii', 'derived_fields/taubeta_red', 'native_fields/baryon_density', 'native_fields/dark_matter_density', 'native_fields/temperature', 'native_fields/velocity_x', 'native_fields/velocity_y', 'native_fields/velocity_z']
# Dimensions:  {}

# %%
loadedSubset = load(dataset, dataset.variables, dimensions={'particles': 0.1})
# Out:
# Read 17 variables from /projects/exasky/data/hacc/SCIDAC_RUNS/128MPC_RUNS_FLAMINGO_DESIGN_3A/FSN_0.5387_VEL_149.279_TEXP_9.613_BETA_0.8710_SEED_1.387e5/output/m000p.full.mpicosmo.567 (8914511260 bytes) in 11.0117s: 772.049 MB/s [excluding header read]

# %%
render(loadedSubset)
# Out:
# ============================================================
# RENDERING DATASET (Server Mode)
# ============================================================
#
# [1/5] Detecting spatial coordinates...
# ✓ Found candidates: ('x', 'y', 'z')
# Use these as positions? [Y/n]:  y
# [2/5] Building position array from: x, y, z
# ✓ Total particles: 26,843,545
#   X range: [0.00, 128.00]
#   Y range: [0.00, 128.00]
#   Z range: [0.00, 128.00]
#
# [3/5] Found 14 scalar fields:
#   • hh
#   • id
#   • mask
#   • mass
#   • mu
#   • phi
#   • rho
#   • status
#   • uu
#   • vx
#   • vy
#   • vz
#   • yhe
#   • zmet
#
# [4/5] Creating 128³ density grids...
#   ✓ Particle density
#   ✓ hh
#   ✓ id
#   ✓ mask
#   ✓ mass
#   ✓ mu
#   ✓ phi
#   ✓ rho
#   ✓ status
#   ✓ uu
#   ✓ vx
#   ✓ vy
#   ✓ vz
#   ✓ yhe
#   ✓ zmet
#
# [5/5] Subsampling particles (factor: 30)...
#   ✓ 894,784 points for visualization
#
# ============================================================
# Creating PyVista scene (off-screen rendering)...
# ============================================================
#   ✓ Adding volume rendering (density grid)
#   ✓ Adding point cloud
#     → Colored by: mass
#
# ============================================================
# ✨ VISUALIZATION READY
# ============================================================
# File: /projects/exasky/data/hacc/SCIDAC_RUNS/128MPC_RUNS_FLAMINGO_DESIGN_3A/FSN_0.5387_VEL_149.279_TEXP_9.613_BETA_0.8710_SEED_1.387e5/output/m000p.full.mpicosmo.567
# Position: (x, y, z)
# Scalars: hh, id, mask, mass, mu, phi, rho, status, uu, vx, vy, vz, yhe, zmet
# Points: 894,784
# Coloring: mass
# ============================================================
#
# Launching Trame viewer...
# Widget(value='<iframe id="pyvista-jupyter_trame__template_P_0x1524a77453d0_1" src="http://127.0.0.1:8888/trame…
# ✓ Trame viewer started successfully

# %%
print(loadedSubset)
# Out:
# File: /projects/exasky/data/nyx/highz/512/NVB_C009_l10n512_S12345T692_z42.hdf5
# Type: HDF5
#
# Available Variables (13):
#   - derived_fields/HI_number_density
#   - derived_fields/HeIII_number_density
#   - derived_fields/tau_local
#   - derived_fields/tau_real
#   - derived_fields/tau_red
#   - derived_fields/tau_red_heii
#   - derived_fields/taubeta_red
#   - native_fields/baryon_density
#   - native_fields/dark_matter_density
#   - native_fields/temperature
#   - native_fields/velocity_x
#   - native_fields/velocity_y
#   - native_fields/velocity_z
#
# ==================================================
# LOADED DATA:
#
# Loaded Variables (13):
#   - derived_fields/HI_number_density: shape=(512, 512, 512), dtype=float32
#   - derived_fields/HeIII_number_density: shape=(512, 512, 512), dtype=float32
#   - derived_fields/tau_local: shape=(512, 512, 512), dtype=float32
#   - derived_fields/tau_real: shape=(512, 512, 512), dtype=float32
#   - derived_fields/tau_red: shape=(512, 512, 512), dtype=float32
#   - derived_fields/tau_red_heii: shape=(512, 512, 512), dtype=float32
#   - derived_fields/taubeta_red: shape=(512, 512, 512), dtype=float32
#   - native_fields/baryon_density: shape=(512, 512, 512), dtype=float32
#   - native_fields/dark_matter_density: shape=(512, 512, 512), dtype=float32
#   - native_fields/temperature: shape=(512, 512, 512), dtype=float32
#   - native_fields/velocity_x: shape=(512, 512, 512), dtype=float32
#   - native_fields/velocity_y: shape=(512, 512, 512), dtype=float32
#   - native_fields/velocity_z: shape=(512, 512, 512), dtype=float32
#
# Selection Applied:
#   - variables_loaded: ['derived_fields/HI_number_density', 'derived_fields/HeIII_number_density', 'derived_fields/tau_local', 'derived_fields/tau_real', 'derived_fields/tau_red', 'derived_fields/tau_red_heii', 'derived_fields/taubeta_red', 'native_fields/baryon_density', 'native_fields/dark_matter_density', 'native_fields/temperature', 'native_fields/velocity_x', 'native_fields/velocity_y', 'native_fields/velocity_z']
#   - dimension_selection: {'particles': 0.1}
#
# Attributes:
#   - format: b'nyx-lyaf'
#   - derived_fields/HI_number_density_shape: (512, 512, 512)
#   - derived_fields/HeIII_number_density_shape: (512, 512, 512)
#   - derived_fields/tau_local_shape: (512, 512, 512)
#   - derived_fields/tau_real_shape: (512, 512, 512)
#   - derived_fields/tau_red_shape: (512, 512, 512)
#   - derived_fields/tau_red_heii_shape: (512, 512, 512)
#   - derived_fields/taubeta_red_shape: (512, 512, 512)
#   - native_fields/baryon_density_shape: (512, 512, 512)
#   - native_fields/dark_matter_density_shape: (512, 512, 512)
#   - native_fields/temperature_shape: (512, 512, 512)
#   - native_fields/velocity_x_shape: (512, 512, 512)
#   - native_fields/velocity_y_shape: (512, 512, 512)
#   - native_fields/velocity_z_shape: (512, 512, 512)
