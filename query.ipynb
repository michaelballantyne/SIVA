# %%
from my_inspect import inspect_file
from my_load import load

info = inspect_file("/projects/exasky/data/hacc/SCIDAC_RUNS/128MPC_RUNS_FLAMINGO_DESIGN_3A/FSN_0.5387_VEL_149.279_TEXP_9.613_BETA_0.8710_SEED_1.387e5/output/m000p.full.mpicosmo.567")
# Out:
# Read 17 variables from /projects/exasky/data/hacc/SCIDAC_RUNS/128MPC_RUNS_FLAMINGO_DESIGN_3A/FSN_0.5387_VEL_149.279_TEXP_9.613_BETA_0.8710_SEED_1.387e5/output/m000p.full.mpicosmo.567 (8914511260 bytes) in 12.1256s: 701.121 MB/s [excluding header read]

# %%
#print(info)

print("xx-----------------------------xx")
print("FileType: ",info.filetype)
print("Variables: ", info.variables)
print("Attributes: ", info.attributes)
print("Dimensions: ", info.dimensions)
# Out:
# xx-----------------------------xx
# FileType:  GenericIO
# Variables:  ['hh', 'id', 'mask', 'mass', 'mu', 'phi', 'rho', 'status', 'uu', 'vx', 'vy', 'vz', 'x', 'y', 'yhe', 'z', 'zmet']
# Attributes:  {'hh_min': 0.0002692521084100008, 'hh_max': 1.0190542936325073, 'id_min': 0.0, 'id_max': 268435455.0, 'mask_min': 2.0, 'mask_max': 647.0, 'mass_min': 0.0, 'mass_max': 24799803392.0, 'mu_min': 0.5920028686523438, 'mu_max': 1.2307692766189575, 'phi_min': -7698195.0, 'phi_max': 1084373.125, 'rho_min': 277284064.0, 'rho_max': 2.9939720865793966e+18, 'status_min': 0.0, 'status_max': 7.0, 'uu_min': 0.6558421850204468, 'uu_max': 221640320.0, 'vx_min': -9743.8349609375, 'vx_max': 10520.03515625, 'vy_min': -9110.4921875, 'vy_max': 11786.8564453125, 'vz_min': -9069.6337890625, 'vz_max': 10658.0341796875, 'x_min': 0.0, 'x_max': 127.99999237060547, 'y_min': 0.0, 'y_max': 127.99999237060547, 'yhe_min': 0.0, 'yhe_max': 0.35453665256500244, 'z_min': 0.0, 'z_max': 127.99999237060547, 'zmet_min': 0.0, 'zmet_max': 0.0555574931204319}
# Dimensions:  {'particles': 268435456}

# %%
subset_10pct = load(info, variables=['x', 'y', 'z', 'hh', 'id'], dimensions={'particles': 0.1})
# Out:
# Read 17 variables from /projects/exasky/data/hacc/SCIDAC_RUNS/128MPC_RUNS_FLAMINGO_DESIGN_3A/FSN_0.5387_VEL_149.279_TEXP_9.613_BETA_0.8710_SEED_1.387e5/output/m000p.full.mpicosmo.567 (8914511260 bytes) in 12.2972s: 691.337 MB/s [excluding header read]

# %%
print(subset_10pct)
# Out:
# File: /projects/exasky/data/hacc/SCIDAC_RUNS/128MPC_RUNS_FLAMINGO_DESIGN_3A/FSN_0.5387_VEL_149.279_TEXP_9.613_BETA_0.8710_SEED_1.387e5/output/m000p.full.mpicosmo.567
# Type: GenericIO
#
# Available Variables (17):
#   - hh
#   - id
#   - mask
#   - mass
#   - mu
#   - phi
#   - rho
#   - status
#   - uu
#   - vx
#   - vy
#   - vz
#   - x
#   - y
#   - yhe
#   - z
#   - zmet
#
# Dimensions:
#   - particles: 268435456
#
# ==================================================
# LOADED DATA:
#
# Loaded Variables (5):
#   - x: shape=(26843545,), dtype=float32
#   - y: shape=(26843545,), dtype=float32
#   - z: shape=(26843545,), dtype=float32
#   - hh: shape=(26843545,), dtype=float32
#   - id: shape=(26843545,), dtype=int64
#
# Selection Applied:
#   - variables_loaded: ['x', 'y', 'z', 'hh', 'id']
#   - total_particles: 268435456
#   - particles_loaded: 26843545
#   - dimension_selection: {'particles': 0.1}
#
# Attributes:
#   - hh_min: 0.0002692521084100008
#   - hh_max: 1.0190542936325073
#   - id_min: 0.0
#   - id_max: 268435455.0
#   - mask_min: 2.0
#   - mask_max: 647.0
#   - mass_min: 0.0
#   - mass_max: 24799803392.0
#   - mu_min: 0.5920028686523438
#   - mu_max: 1.2307692766189575
#   - phi_min: -7698195.0
#   - phi_max: 1084373.125
#   - rho_min: 277284064.0
#   - rho_max: 2.9939720865793966e+18
#   - status_min: 0.0
#   - status_max: 7.0
#   - uu_min: 0.6558421850204468
#   - uu_max: 221640320.0
#   - vx_min: -9743.8349609375
#   - vx_max: 10520.03515625
#   - vy_min: -9110.4921875
#   - vy_max: 11786.8564453125
#   - vz_min: -9069.6337890625
#   - vz_max: 10658.0341796875
#   - x_min: 0.0
#   - x_max: 127.99999237060547
#   - y_min: 0.0
#   - y_max: 127.99999237060547
#   - yhe_min: 0.0
#   - yhe_max: 0.35453665256500244
#   - z_min: 0.0
#   - z_max: 127.99999237060547
#   - zmet_min: 0.0
#   - zmet_max: 0.0555574931204319
