# %%
from my_inspect import inspect_file
from my_load import load
from my_download import download
from my_render import render

info = inspect_file("/projects/exasky/data/hacc/SCIDAC_RUNS/128MPC_RUNS_FLAMINGO_DESIGN_3A/FSN_0.5387_VEL_149.279_TEXP_9.613_BETA_0.8710_SEED_1.387e5/output/m000p.full.mpicosmo.567")
# Out:
# Read 17 variables from /projects/exasky/data/hacc/SCIDAC_RUNS/128MPC_RUNS_FLAMINGO_DESIGN_3A/FSN_0.5387_VEL_149.279_TEXP_9.613_BETA_0.8710_SEED_1.387e5/output/m000p.full.mpicosmo.567 (8914511260 bytes) in 12.34s: 688.944 MB/s [excluding header read]

# %%
#print(info)

print("xx-----------------------------xx")
print("FileType: ",info.filetype)
print("Variables: ", info.variables)
print("Attributes: ", info.attributes)
print("Dimensions: ", info.dimensions)
# Out:
# xx-----------------------------xx
# FileType:  GenericIO
# Variables:  ['hh', 'id', 'mask', 'mass', 'mu', 'phi', 'rho', 'status', 'uu', 'vx', 'vy', 'vz', 'x', 'y', 'yhe', 'z', 'zmet']
# Attributes:  {'hh_min': 0.0002692521084100008, 'hh_max': 1.0190542936325073, 'id_min': 0.0, 'id_max': 268435455.0, 'mask_min': 2.0, 'mask_max': 647.0, 'mass_min': 0.0, 'mass_max': 24799803392.0, 'mu_min': 0.5920028686523438, 'mu_max': 1.2307692766189575, 'phi_min': -7698195.0, 'phi_max': 1084373.125, 'rho_min': 277284064.0, 'rho_max': 2.9939720865793966e+18, 'status_min': 0.0, 'status_max': 7.0, 'uu_min': 0.6558421850204468, 'uu_max': 221640320.0, 'vx_min': -9743.8349609375, 'vx_max': 10520.03515625, 'vy_min': -9110.4921875, 'vy_max': 11786.8564453125, 'vz_min': -9069.6337890625, 'vz_max': 10658.0341796875, 'x_min': 0.0, 'x_max': 127.99999237060547, 'y_min': 0.0, 'y_max': 127.99999237060547, 'yhe_min': 0.0, 'yhe_max': 0.35453665256500244, 'z_min': 0.0, 'z_max': 127.99999237060547, 'zmet_min': 0.0, 'zmet_max': 0.0555574931204319}
# Dimensions:  {'particles': 268435456}

# %%
subset_10pct = load(info, info.variables, dimensions={'particles': 0.1})
# Out:
# Read 17 variables from /projects/exasky/data/hacc/SCIDAC_RUNS/128MPC_RUNS_FLAMINGO_DESIGN_3A/FSN_0.5387_VEL_149.279_TEXP_9.613_BETA_0.8710_SEED_1.387e5/output/m000p.full.mpicosmo.567 (8914511260 bytes) in 9.13915s: 930.233 MB/s [excluding header read]

# %%
print(subset_10pct)

# %%
download(subset_10pct, "output/mydata.cpio")

# %%
render(subset_10pct)
# Out:
# ============================================================
# RENDERING DATASET (Server Mode)
# ============================================================
#
# [1/5] Detecting spatial coordinates...
# ✓ Found candidates: ('x', 'y', 'z')
# Use these as positions? [Y/n]:  y
# [2/5] Building position array from: x, y, z
# ✓ Total particles: 26,843,545
#   X range: [0.00, 128.00]
#   Y range: [0.00, 128.00]
#   Z range: [0.00, 128.00]
#
# [3/5] Found 14 scalar fields:
#   • hh
#   • id
#   • mask
#   • mass
#   • mu
#   • phi
#   • rho
#   • status
#   • uu
#   • vx
#   • vy
#   • vz
#   • yhe
#   • zmet
#
# [4/5] Creating 128³ density grids...
#   ✓ Particle density
#   ✓ hh
#   ✓ id
#   ✓ mask
#   ✓ mass
#   ✓ mu
#   ✓ phi
#   ✓ rho
#   ✓ status
#   ✓ uu
#   ✓ vx
#   ✓ vy
#   ✓ vz
#   ✓ yhe
#   ✓ zmet
#
# [5/5] Subsampling particles (factor: 30)...
#   ✓ 894,784 points for visualization
#
# ============================================================
# Creating PyVista scene (off-screen rendering)...
# ============================================================
# 2026-06-04 15:06:45.158 ( 130.365s) [    150B5D17D400]vtkXOpenGLRenderWindow.:1460  WARN| bad X server connection. DISPLAY=
#   ✓ Adding volume rendering (density grid)
#   ✓ Adding point cloud
#     → Colored by: mass
#
# ============================================================
# ✨ VISUALIZATION READY
# ============================================================
# File: /projects/exasky/data/hacc/SCIDAC_RUNS/128MPC_RUNS_FLAMINGO_DESIGN_3A/FSN_0.5387_VEL_149.279_TEXP_9.613_BETA_0.8710_SEED_1.387e5/output/m000p.full.mpicosmo.567
# Position: (x, y, z)
# Scalars: hh, id, mask, mass, mu, phi, rho, status, uu, vx, vy, vz, yhe, zmet
# Points: 894,784
# Coloring: mass
# ============================================================
#
# Launching Trame viewer...
# Widget(value='<iframe id="pyvista-jupyter_trame__template_P_0x150b3ba5a690_0" src="http://localhost:8888/trame…
# ✓ Trame viewer started successfully
